# %%
# !git clone 'https://github.com/tnwei/waternet'
# Out:
# Cloning into 'waternet'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 131 (delta 30), reused 29 (delta 29), pack-reused 95
# Receiving objects: 100% (131/131), 468.06 KiB | 4.59 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
# !pip install -r waternet/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 68.7 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %% [markdown]
# ### Upload The Images

# %%
# !unzip "file (3).zip"
# Out:
# Archive:  file (3).zip
#    creating: content/datasets/oysters-11/valid/images/
#   inflating: content/datasets/oysters-11/valid/images/Shotcut_00_02_45_612_png_jpg.rf.0311837d27cfcaf4959ebe0e04bb5f33.jpg
#   inflating: content/datasets/oysters-11/valid/images/Shotcut_00_01_06_720-Copy-Copy_png_jpg.rf.88f4a49d4b0829b69c4ce1c0bdeb05be.jpg
#   inflating: content/datasets/oysters-11/valid/images/17_jpg.rf.527188db7f6a033fabb359bbf2a45191.jpg
#   inflating: content/datasets/oysters-11/valid/images/Shotcut_00_05_53_303_png_jpg.rf.98418f159cd24595236f3f3284f62da1.jpg
#   inflating: content/datasets/oysters-11/valid/images/Chesapeake-Bay-Oysters-Underwater-View-1-_375_jpg.rf.62f14a743499c14f2b8c2f9efb689b1f.jpg
#   inflating: content/datasets/oysters-11/valid/images/74_jpg.rf.9d729a9a2b77216752229133b50dbc24.jpg
#   inflating: content/datasets/oysters-11/valid/images/Shotcut_00_01_18_310_png_jpg.rf.38a84abb263b5a3de2ea37f5d6831ecb.jpg
# ...

# %%
# !mkdir /content/output
# !python waternet/inference.py --source '/content/content/datasets/oysters-11/valid/images' --name '/content/output'
# Out:
# mkdir: cannot create directory ‘/content/output’: File exists
# Using device: cpu
# No weights specified in --weights, using default: waternet_exported_state_dict-daa0ee.pt
# Total images/videos: 71
# Saved output to /content/output!

# %%
# !zip -r /content/file.zip /content/output
from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/output/ (stored 0%)
#   adding: content/output/Chesapeake-Bay-Oysters-Underwater-View-1-_284_jpg.rf.a9db2e90862b95e7d220378cacb9f914.jpg (deflated 2%)
#   adding: content/output/17_jpg.rf.ff0b8ec21fffc00ee594b128a9ced5f0.jpg (deflated 1%)
#   adding: content/output/OpenOyster11_png_jpg.rf.78c608710de3bb39aa833044158ffeeb.jpg (deflated 2%)
#   adding: content/output/Shotcut_00_08_20_604_png_jpg.rf.0d6900297b2e139d8a849be4a49548e8.jpg (deflated 1%)
#   adding: content/output/Shotcut_00_01_10_360_png_jpg.rf.9dcd2fffcd3b99d45609e55d86045042.jpg (deflated 1%)
#   adding: content/output/9_png_jpg.rf.bf0de68f705483cb7f78911d0ae6e508.jpg (deflated 2%)
#   adding: content/output/Chesapeake-Bay-Oysters-Underwater-View-1-_338_jpg.rf.c6cf17049e57ad838045b0c8d5072b9d.jpg (deflated 2%)
#   adding: content/output/9_png_jpg.rf.ad8ca920c8acfe880038025ab5d1703b.jpg (deflated 2%)
# ...

# %% [markdown]
# ###Look at ze images
