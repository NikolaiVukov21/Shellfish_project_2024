# %%
# %pip install sql
# Out:
# Requirement already satisfied: sql in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (2022.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install av
# Out:
# Requirement already satisfied: av in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (12.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pillow
# Out:
# Requirement already satisfied: pillow in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (10.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install numpy==2.0
# Out:
# Requirement already satisfied: numpy==2.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (2.0.0)

# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from sqlalchemy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (2.0.31)
# Requirement already satisfied: sqlparse in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: backcall in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pickleshare in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: stack-data in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install roboflow
# Out:
# Requirement already satisfied: roboflow in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (1.1.31)
# Requirement already satisfied: certifi==2023.7.22 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (3.9.0)
# Requirement already satisfied: numpy>=1.18.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (2.0.0)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (10.3.0)
# Requirement already satisfied: python-dateutil in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install git+https://github.com/THU-MIG/yolov10.git
# Out:
# Collecting git+https://github.com/THU-MIG/yolov10.git
#   Cloning https://github.com/THU-MIG/yolov10.git to /tmp/pip-req-build-6a5yn242
#   Running command git clone --filter=blob:none --quiet https://github.com/THU-MIG/yolov10.git /tmp/pip-req-build-6a5yn242
#   Resolved https://github.com/THU-MIG/yolov10.git to commit aad320dd80b56694e590c950b25060a134966496
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.3.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (3.9.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (2.3.1)
# Requirement already satisfied: torchvision>=0.9.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (4.66.4)
# Requirement already satisfied: psutil in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from ultralytics==8.1.34) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from ultralytics==8.1.34) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2023.7.22)
# Requirement already satisfied: filelock in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.12.2)
# Requirement already satisfied: sympy in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.12.1)
# Requirement already satisfied: networkx in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.2.1)
# Requirement already satisfied: jinja2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.4)
# Requirement already satisfied: fsspec in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.1.34) (12.5.40)
# Requirement already satisfied: six in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics==8.1.34) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics==8.1.34) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.34) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install supervision
# Out:
# Requirement already satisfied: supervision in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from supervision) (3.9.0)
# Requirement already satisfied: numpy>=1.21.2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from supervision) (2.0.0)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from supervision) (4.8.0.74)
# Requirement already satisfied: pillow>=9.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from supervision) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from supervision) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from supervision) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from matplotlib>=3.6.0->supervision) (6.4.0)
# Requirement already satisfied: six in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->supervision) (3.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (0.23.4)
# Requirement already satisfied: filelock in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests->huggingface_hub) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests->huggingface_hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from requests->huggingface_hub) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install bottleneck==1.3.6
# Out:
# Requirement already satisfied: bottleneck==1.3.6 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (1.3.6)
# Requirement already satisfied: numpy in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from bottleneck==1.3.6) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numexpr==2.8.4
# Out:
# Requirement already satisfied: numexpr==2.8.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (2.8.4)
# Requirement already satisfied: numpy>=1.13.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from numexpr==2.8.4) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wget
# Out:
# Requirement already satisfied: wget in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gcloud
# Out:
# Requirement already satisfied: gcloud in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (0.18.3)
# Requirement already satisfied: httplib2>=0.9.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from gcloud) (0.15.0)
# Requirement already satisfied: googleapis-common-protos in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from gcloud) (1.63.2)
# Requirement already satisfied: oauth2client>=2.0.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from gcloud) (4.1.3)
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from gcloud) (5.27.2)
# Requirement already satisfied: six in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from gcloud) (1.16.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client>=2.0.1->gcloud) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client>=2.0.1->gcloud) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client>=2.0.1->gcloud) (4.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install google
# Out:
# Requirement already satisfied: google in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from beautifulsoup4->google) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (2.17.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (2.30.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (2.19.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (2.7.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-cloud-storage) (1.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (5.27.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/linuxlab/home/mstaus1/.local/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2023.7.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install httplib2==0.15.0 google-api-python-client==1.6
# Out:
# Requirement already satisfied: httplib2==0.15.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (0.15.0)
# Requirement already satisfied: google-api-python-client==1.6 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (1.6.0)
# Requirement already satisfied: oauth2client<5.0.0dev,>=1.5.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-python-client==1.6) (4.1.3)
# Requirement already satisfied: six<2dev,>=1.6.1 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-python-client==1.6) (1.16.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from google-api-python-client==1.6) (3.0.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client==1.6) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client==1.6) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/.conda/lib/python3.9/site-packages (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client==1.6) (4.9)

# %%
# !pip install numpy==1.5.0
# Out:
# Collecting numpy==1.5.0
#   Downloading numpy-1.5.0.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [707 lines of output]
#       Converting to Python3 via 2to3...
#       RefactoringTool: Skipping optional fixer: buffer
#       RefactoringTool: Skipping optional fixer: idioms
#       RefactoringTool: Skipping optional fixer: set_literal
#       RefactoringTool: Skipping optional fixer: ws_comma
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/_import_tools.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/dual.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/version.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matlib.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/add_newdocs.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ctypeslib.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/_inspect.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/chebyshev.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polynomial.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polytemplate.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polyutils.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_polynomial.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_polyutils.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_chebyshev.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/compat.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/nd_image.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/numerictypes.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/session.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/matrix.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/functions.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/setupscons.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/alter_code1.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/convolve.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/util.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/ufuncs.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/alter_code2.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/linear_algebra.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/image.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/random_array.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/info.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/arraysetops.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/_iotools.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/_datasource.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/twodim_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/polynomial.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/setupscons.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/scimath.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/recfunctions.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/function_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/financial.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/npyio.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/utils.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/user_array.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/ufunclike.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/shape_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/format.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/index_tricks.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/type_check.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/stride_tricks.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/benchmarks/bench_arraysetops.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_polynomial.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_type_check.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_index_tricks.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_twodim_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test__datasource.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_recfunctions.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_stride_tricks.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_io.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_financial.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_format.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test__iotools.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_function_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_utils.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_ufunclike.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_regression.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_shape_base.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_arraysetops.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/basics.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/internals.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/byteswapping.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/constants.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/indexing.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/misc.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/structured_arrays.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/performance.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/broadcasting.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/howtofind.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/io.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/jargon.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/subclassing.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/creation.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/ufuncs.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/glossary.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/doc/methods_vs_functions.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/mrecords.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/version.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/testutils.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/extras.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/bench.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_extras.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_mrecords.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_subclassing.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_regression.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/info.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/tests/test_random.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/info.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/fftpack.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/helper.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/tests/test_helper.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/tests/test_fftpack.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/scons_support.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/info.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/getlimits.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/records.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/machar.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/numerictypes.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/fromnumeric.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/_mx_datetime_parser.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/_internal.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/function_base.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/setup_common.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/numeric.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/arrayprint.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/shape_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/memmap.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/numpy_api.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/ufunc_docstrings.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/cversions.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/genapi.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_scalarmath.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_numeric.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_arrayprint.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_unicode.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_errstate.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_defchararray.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_records.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_blasdot.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_getlimits.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_dtype.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_umath_complex.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_memmap.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_machar.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_print.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_ufunc.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_umath.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_multiarray.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_function_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_regression.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_shape_base.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/tests/test_numerictypes.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/ccompiler.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/cpuinfo.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/line_endings.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/info.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/compat.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/exec_command.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/from_template.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/core.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/unixccompiler.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/mingw32ccompiler.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/log.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/setupscons.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/__version__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/interactive.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/extension.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/misc_util.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/intelccompiler.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/npy_pkg_config.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/conv_template.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/environment.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/lib2def.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/ibm.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/pg.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/intel.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/absoft.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/mips.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/gnu.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/g95.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/none.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/hpux.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/compaq.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/sun.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/vast.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/nag.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/fcompiler/lahey.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/install_clib.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build_ext.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/install.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/develop.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build_scripts.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/bdist_rpm.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/config.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/install_headers.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/scons.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build_py.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build_src.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/autodist.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/sdist.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/install_data.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/config_compiler.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build_clib.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/egg_info.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/command/build.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/test_misc_util.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/test_fcompiler_gnu.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/test_npy_pkg_config.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_f90_ext/tests/test_foo.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/gen_ext/tests/test_fib3.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/swig_ext/tests/test_example.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/swig_ext/tests/test_example2.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_ext/tests/test_fib2.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/pyrex_ext/tests/test_primes.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/nosetester.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/nulltester.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/decorators.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/utils.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/numpytest.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/noseclasses.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/tests/test_decorators.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/tests/test_utils.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/typeconv.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/rng.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/compat.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/array_printer.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/misc.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/matrix.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/functions.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/alter_code1.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/fix_default_axis.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/arrayfns.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/fft.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/__init__.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/user_array.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/mlab.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/precision.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/rng_stats.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/ufuncs.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/alter_code2.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/linear_algebra.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/random_array.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/tests/test_oldnumeric.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/tests/test_regression.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/defmatrix.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/tests/test_defmatrix.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/tests/test_multiarray.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/tests/test_regression.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/info.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/linalg.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/tests/test_linalg.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/tests/test_build.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/tests/test_regression.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/use_rules.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/info.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/f90mod_rules.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/cfuncs.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/f2py2e.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/capi_maps.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/f2py_testing.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/crackfortran.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/setupscons.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/rules.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/__version__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/diagnose.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/__init__.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/common_rules.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/cb_rules.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/func2subr.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/docs/usersguide/setup_example.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_mixed.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_array_from_pyobj.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_logical.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_integer.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_character.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_callback.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/util.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_real.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_complex.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/tests/test_ctypeslib.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/tests/test_matlib.py
#       RefactoringTool: Files that were modified:
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/_import_tools.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/dual.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/version.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matlib.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/setupscons.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/__init__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/add_newdocs.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ctypeslib.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/_inspect.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/setupscons.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/__init__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/chebyshev.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polynomial.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polytemplate.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/__init__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/polyutils.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_polynomial.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_polyutils.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/tests/test_chebyshev.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/compat.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/nd_image.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/numerictypes.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/session.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/matrix.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/functions.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/setupscons.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/alter_code1.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/__init__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/convolve.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/util.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/ufuncs.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/alter_code2.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/linear_algebra.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/image.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/random_array.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/info.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/arraysetops.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/_iotools.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/_datasource.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/twodim_base.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/polynomial.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/setupscons.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/scimath.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/recfunctions.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/function_base.py
# ...
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/f2py2e.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/capi_maps.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/f2py_testing.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/crackfortran.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/setupscons.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/rules.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/__version__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/diagnose.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/__init__.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/common_rules.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/cb_rules.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/func2subr.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/docs/usersguide/setup_example.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_mixed.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_array_from_pyobj.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_logical.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_integer.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_character.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_callback.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/util.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_real.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/tests/test_return_complex.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/tests/test_ctypeslib.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/tests/test_matlib.py
#       RefactoringTool: Warnings/messages while refactoring:
#       RefactoringTool: ### In file /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/_iotools.py ###
#       RefactoringTool: Line 689: You should use a for loop here
#       RefactoringTool: ### In file /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/fromnumeric.py ###
#       RefactoringTool: Line 342: You should use 'operator.mul(repeats, axis)' here.
#       RefactoringTool: Skipping optional fixer: buffer
#       RefactoringTool: Skipping optional fixer: idioms
#       RefactoringTool: Skipping optional fixer: set_literal
#       RefactoringTool: Skipping optional fixer: ws_comma
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/setup.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/setup.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_numpy_api.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_umath.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_ufunc_api.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_f90_ext/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/gen_ext/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/swig_ext/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_ext/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/pyrex_ext/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/setup.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/setup.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/setup.py
#       RefactoringTool: Files that were modified:
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/polynomial/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/numarray/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/random/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/fft/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_numpy_api.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_umath.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/code_generators/generate_ufunc_api.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_f90_ext/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/gen_ext/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/swig_ext/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/f2py_ext/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/tests/pyrex_ext/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/testing/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/matrixlib/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/linalg/setup.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/setup.py
#       RefactoringTool: Skipping optional fixer: buffer
#       RefactoringTool: Skipping optional fixer: idioms
#       RefactoringTool: Skipping optional fixer: set_literal
#       RefactoringTool: Skipping optional fixer: ws_comma
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/py3k.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/defchararray.py
#       RefactoringTool: Files that were modified:
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/compat/py3k.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/core/defchararray.py
#       RefactoringTool: Skipping optional fixer: buffer
#       RefactoringTool: Skipping optional fixer: idioms
#       RefactoringTool: Skipping optional fixer: set_literal
#       RefactoringTool: Skipping optional fixer: ws_comma
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/arrayterator.py
#       RefactoringTool: No changes to /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_arrayterator.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/core.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/timer_comparison.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_old_ma.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_core.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/system_info.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/ma.py
#       RefactoringTool: Refactored /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/auxfuncs.py
#       RefactoringTool: Files that were modified:
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/arrayterator.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/lib/tests/test_arrayterator.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/core.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/timer_comparison.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_old_ma.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_core.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/system_info.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/oldnumeric/ma.py
#       RefactoringTool: /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/f2py/auxfuncs.py
#       RefactoringTool: Warnings/messages while refactoring:
#       RefactoringTool: ### In file /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_old_ma.py ###
#       RefactoringTool: Line 298: You should use 'operator.mul(x4, (2, 2, 2, 2), axis=0)' here.
#       RefactoringTool: Line 300: You should use 'operator.mul(x4, 2, axis=0)' here.
#       RefactoringTool: ### In file /tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/ma/tests/test_core.py ###
#       RefactoringTool: Line 330: You should use 'operator.mul(x4, (2, 2, 2, 2), axis=0)' here.
#       RefactoringTool: Line 332: You should use 'operator.mul(x4, 2, axis=0)' here.
#       Running from numpy source directory./tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/misc_util.py:425: SyntaxWarning: "is" with a literal. Did you mean "=="?
#         return is_string(s) and ('*' in s or '?' is s)
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/setup.py", line 211, in <module>
#           setup_package()
#         File "/tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/setup.py", line 188, in setup_package
#           from numpy.distutils.core import setup
#         File "/tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/__init__.py", line 22, in <module>
#           import numpy.distutils.ccompiler
#         File "/tmp/pip-install-oiws278p/numpy_e5341c46881e49b9afa3e1182ab276cb/build/py3k/numpy/distutils/ccompiler.py", line 22, in <module>
#           _old_init_posix = distutils.sysconfig._init_posix
#       AttributeError: module 'distutils.sysconfig' has no attribute '_init_posix'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import pymysql
from pymysql.err import IntegrityError, OperationalError
import os
from PIL import Image
import numpy as np
import supervision as sv
import cv2
import av
from PIL import Image
import shutil as sh
import re
from roboflow import Roboflow
import cv2
from ultralytics import YOLOv10
import wget
from time import time
from gcloud import storage
from oauth2client.service_account import ServiceAccountCredentials
import os
import json

# %%
temp_folder = os.path.join('.', 'Files_local')
temp_weights = os.path.join(temp_folder, 'Weights')

# %%
bba = sv.BoxCornerAnnotator()
la = sv.LabelAnnotator(text_scale = 0.4, text_padding = 1)

def annotate_image(input_img, model, label_annotator = la, bounding_box_annotator = bba, verbose = False, conf = True, conf_level = 0.05):
    
    cont_img = np.ascontiguousarray(input_img, dtype=np.uint8)
    results = model(cont_img, conf=conf_level, verbose = verbose)[0]
    conf_array = np.array(results.boxes.conf.cpu())
    conf_ls_str  = [str(round(x * 100) ) + '%' for x in conf_array]
    tot_time = sum([x for x in results.speed.values()])
    
    detections = sv.Detections.from_ultralytics(results)
    annotated_image = bounding_box_annotator.annotate(
        scene=input_img, detections=detections)
    num_oysters = detections.xyxy.shape[0]
    annotated_image = label_annotator.annotate(
        scene=annotated_image, detections=detections, labels = conf_ls_str)
    return(annotated_image, num_oysters, tot_time, detections)


def annotate_video(input_vid, model, out_location = '.', im_width = 416, im_height = 416, conf_level = 0.3):
    tot_oysters = 0
    tot_frame = 0
    
    bba = sv.BoundingBoxAnnotator()
    la = sv.LabelAnnotator()

    container = av.open(input_vid)
    stream_vid = container.streams.video[0]
    fname = input_vid.rsplit('/', 1)[-1]
    per_index = fname.index('.')
    out_path = os.path.join(out_location, f'{fname[:per_index]}_annotated.mp4')
    outp = av.open(out_path, 'w')
    codec_name = stream_vid.codec_context.name
    fps = stream_vid.codec_context.rate
    output_stream = outp.add_stream(codec_name, str(fps))
    output_stream.width = im_width
    output_stream.height = im_height
    output_stream.pix_fmt = stream_vid.codec_context.pix_fmt
    start = time()
    for index, frame in enumerate(container.decode(stream_vid)):
        pil_img = frame.to_image()
        np_img = np.array(pil_img)
        np_img_resize = cv2.resize(np_img, (im_width, im_height))
        np_rot = np_img_resize[:, :, ::-1]
        small_pil_img = Image.fromarray(np_rot)
        np_image_2 = np.array(small_pil_img)
        an_mg, num_oysters, _, _2z = annotate_image(np_image_2, model, conf_level = conf_level)
        tot_oysters += num_oysters
        frame_out = av.VideoFrame.from_ndarray(an_mg, format='bgr24')
        pkt = output_stream.encode(frame_out)
        outp.mux(pkt)
    end = time()
    net_time = end - start
    container.close()
    outp.close()
    ann_rate = (index / fps) / net_time # ratio of time to annotate versus length of video
    return tot_oysters / index, net_time, out_path, ann_rate

# %%
def get_ext(fpath):
    fname = fpath.rsplit('/', 1)[-1]
    per_index = fname.index('.')
    ext = fname[per_index + 1:].lower()
    return ext

def get_id_fname(f_out, fpath, id):
    fname = fpath.rsplit('/', 1)[-1]
    per_index = fname.index('.')
    ext = fname[per_index + 1:].lower()
    return os.path.join(f_out, f"{fname[:per_index]}-{id}.{ext}")

def get_REPLACE_ID(column_id = 'Raw_File_ID', table='raw_files', column_rep='Filepath'):
    cur.execute(f"""SELECT {column_id} from {table} where {column_rep} = 'REPLACE'""")
    id = cur.fetchall()[-1][column_id]
    return id

def get_match(pattern, string):
    matches = re.search(pattern, string)
    if matches:
        print(matches.group(1))
        return(matches.group(1))
    else:
        raise ValueError(f'Improper string exported, couldn\'t find {pattern} in the given text')



def delete_folder(name, base = "."):
    fpath = os.path.join(base, name)
    if os.path.exists(fpath):
        for item in os.listdir(fpath):
            new_path = os.path.join(fpath, item)
            if os.path.isfile(new_path):
                os.remove(new_path)
            elif os.path.isdir(new_path):
                delete_folder(item, fpath)
        os.rmdir(fpath)
                
def make_folder(fpath, overwrite = False):
    delete_folder(fpath, '.') if overwrite else None
    if os.path.exists(fpath):
        
        print(f"{fpath} already exists")
    else:
        os.mkdir(fpath)
        
def get_temp_fname(fpath, temp_f = temp_folder):
    fname = fpath.rsplit('/', 1)[-1]
    return os.path.join(temp_folder, fname)

def trim_file_depth(fpath, start = 0, end = 'Unused'):
    split_ls = fpath.rsplit('/')
    if end == 'Unused':
        end = len(split_ls)
    return '/'.join(split_ls[start:end])

# %%
import json
class Storage_Manager:
    def __init__(self, JSON_file = 'molten-album-427115-q6-cfa4e4aaf3bd.json'):
        self.bkt, self.cl = self.sign_in_storage_g(JSON_file)


    def sign_in_storage_g(self, JSON_file = 'molten-album-427115-q6-cfa4e4aaf3bd.json'):
        f = open(JSON_file)
        credentials_dict = json.load(f)
        credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials_dict)
        client = storage.Client(credentials=credentials, project='molten-album-427115-q6')
        bkt = client.get_bucket('test_bucket_abc123')
        return bkt, client

    def upload_file_g(self, file_to_upload, new_name_with_path_g):
        blob = self.bkt.blob(new_name_with_path_g)
        blob.upload_from_filename(file_to_upload)

    def upload_folder_g(folder_to_upload, new_name_with_path_g, level = 0, overwrite = False):
        already_uploaded = False
        if level == 0: # check if already uploaded
            already_uploaded = check_folder_exists_g(folder_to_upload, new_name_with_path_g)
            level += 1
        if os.path.exists(folder_to_upload) and (not already_uploaded or overwrite):
            for item in os.listdir(folder_to_upload):
                cur_path = os.path.join(folder_to_upload, item)
                new_path_g = os.path.join(new_name_with_path_g, item)
                if os.path.isfile(cur_path):
                    self.upload_file_g(cur_path, new_path_g)
                elif os.path.isdir(new_path_g):
                    self.upload_folder_g(cur_path, new_path_g, level)       

    def check_folder_exists_g(self, folder_to_upload, check_location, disable = False, full = False):
        # assumes if one file is in the right location then they all are if full = False
        try:
            if disable:
                return True
            cur_path = folder_to_upload
            path_check_exist_g = check_location
            if not os.path.exists(cur_path):
                return False
            all_items = os.listdir(cur_path)
            for added_item in all_items: # searching for a file
                cur_path = os.path.join(cur_path, added_item)
                path_check_exist_g = os.path.join(path_check_exist_g, added_item)
                cur_exists = False
                if os.path.isfile(cur_path): # if you just want to make sure one file is the same, set full to 
                    cur_exists = path_exists_g(path_check_exist_g)
                    if not full: 
                        return cur_exists
                elif os.path.isdir(cur_path):
                    cur_exists = check_folder_exists_g(cur_path, path_check_exist_g)
                if not cur_exists:
                    return False
            return True
        except Exception:
            print(f"Current folder {folder_to_upload} or {check_location} is malformed")
            return False 

    def download_file_g(self, file_to_download_g, new_name_with_path):
        if not os.path.exists(new_name_with_path):
            blob = self.bkt.blob(file_to_download_g)
            blob.download_to_filename(new_name_with_path)

    def list_blobs_g(self, folder_base):
        """Lists all the blobs in the bucket that begin with the prefix."""
        blobs = self.bkt.list_blobs(prefix=folder_base)
        return blobs

    def download_folder_g(self, folder_to_download_g, new_name_with_path, overwrite = False, level = 0, file_depth = 3):
        already_uploaded = False
        if level == 0: # check if already downloaded
            already_uploaded = os.path.exists(new_name_with_path)
            level += 1
        if not check_folder_exists_g(new_name_with_path, folder_to_download_g) and (not already_uploaded or overwrite):
            for item in list_blobs_g(folder_to_download_g):
                file_path_g = item.name
                file_name = trim_file_depth(file_path_g, start = file_depth)
                local_path = os.path.join(new_name_with_path, file_name)
                self.download_file_g(file_path_g, local_path)      

    def make_folder_g(self, folder_name):
        blob = self.bkt.blob(folder_name + '/')
        blob.upload_from_string('')

    def path_exists_g(self, file):
        blob = self.bkt.blob(file)
        return blob.exists()

# %%
t = Storage_Manager()

# %%
class LocalFileHelper():
    def __init__(self):
        pass

    def get_ext(self, fpath):
        fname = fpath.rsplit('/', 1)[-1]
        per_index = fname.index('.')
        ext = fname[per_index + 1:].lower()
        return ext

    def get_id_fname(self, f_out, fpath, id):
        fname = fpath.rsplit('/', 1)[-1]
        per_index = fname.index('.')
        ext = fname[per_index + 1:].lower()
        return os.path.join(f_out, f"{fname[:per_index]}-{id}.{ext}")

    def get_REPLACE_ID(self, column_id = 'Raw_File_ID', table='raw_files', column_rep='Filepath'):
        cur.execute(f"""SELECT {column_id} from {table} where {column_rep} = 'REPLACE'""")
        id = cur.fetchall()[-1][column_id]
        return id

    def get_match(self, pattern, string):
        matches = re.search(pattern, string)
        if matches:
            print(matches.group(1))
            return(matches.group(1))
        else:
            raise ValueError(f'Improper string exported, couldn\'t find {pattern} in the given text')

    def delete_folder(self, name, base = "."):
        fpath = os.path.join(base, name)
        if os.path.exists(fpath):
            for item in os.listdir(fpath):
                new_path = os.path.join(fpath, item)
                if os.path.isfile(new_path):
                    os.remove(new_path)
                elif os.path.isdir(new_path):
                    delete_folder(item, fpath)
            os.rmdir(fpath)
                    
    def make_folder(self, fpath, overwrite = False):
        delete_folder(fpath, '.') if overwrite else None
        if os.path.exists(fpath):
            print(f"{fpath} already exists")
        else:
            os.mkdir(fpath)
            
    def get_temp_fname(self, fpath, temp_f = temp_folder):
        fname = fpath.rsplit('/', 1)[-1]
        return os.path.join(temp_folder, fname)

    def trim_file_depth(self, fpath, start = 0, end = 'Unused'):
        split_ls = fpath.rsplit('/')
        if end == 'Unused':
            end = len(split_ls)
        return '/'.join(split_ls[start:end])

# %%
import json
def sign_in_storage_g(JSON_file = 'molten-album-427115-q6-cfa4e4aaf3bd.json'):
    f = open(JSON_file)
    credentials_dict = json.load(f)
    credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials_dict)
    client = storage.Client(credentials=credentials, project='molten-album-427115-q6')
    bkt = client.get_bucket('test_bucket_abc123')
    return bkt, client

b, cl = sign_in_storage_g()

# %%
def check_folder_exists_g(folder_to_upload, check_location, disable = False, full = False, bkt = b): # assume full installation
    # assumes if one file is in the right location then they all are
    try:
        if disable:
            return True
        cur_path = folder_to_upload
        path_check_exist_g = check_location
        if not os.path.exists(cur_path):
            return False
        all_items = os.listdir(cur_path)
        for added_item in all_items: # searching for a file
            cur_path = os.path.join(cur_path, added_item)
            path_check_exist_g = os.path.join(path_check_exist_g, added_item)
            cur_exists = False
            if os.path.isfile(cur_path): # if you just want to make sure one file is the same, set full to 
                cur_exists = path_exists_g(path_check_exist_g)
                if not full: 
                    return cur_exists
            elif os.path.isdir(cur_path):
                cur_exists = check_folder_exists_g(cur_path, path_check_exist_g)
            if not cur_exists:
                return False
        return True
    except Exception:
        print(f"Current folder {folder_to_upload} or {check_location} is malformed")
        return False

def upload_file_g(file_to_upload, new_name_with_path_g, bkt = b):
    blob = bkt.blob(new_name_with_path_g)
    blob.upload_from_filename(file_to_upload)
    

def upload_folder_g(folder_to_upload, new_name_with_path_g, bkt = b , level = 0, overwrite = False):
    already_uploaded = False
    if level == 0: # check if already uploaded
        already_uploaded = check_folder_exists_g(folder_to_upload, new_name_with_path_g)
        level += 1
    if os.path.exists(folder_to_upload) and (not already_uploaded or overwrite):
        for item in os.listdir(folder_to_upload):
            cur_path = os.path.join(folder_to_upload, item)
            new_path_g = os.path.join(new_name_with_path_g, item)
            if os.path.isfile(cur_path):
                upload_file_g(cur_path, new_path_g)
            elif os.path.isdir(new_path_g):
                upload_folder_g(cur_path, new_path_g, level)

def download_file_g(file_to_download_g, new_name_with_path, bkt = b):
    if not os.path.exists(new_name_with_path):
        blob = bkt.blob(file_to_download_g)
        blob.download_to_filename(new_name_with_path)

def list_blobs_g(folder_base, bkt = b, client = cl):
    """Lists all the blobs in the bucket that begin with the prefix."""
    blobs = bkt.list_blobs(prefix=folder_base)
    return blobs

def download_folder_g(folder_to_download_g, new_name_with_path, overwrite = False, level = 0, file_depth = 3):
    already_uploaded = False
    if level == 0: # check if already downloaded
        already_uploaded = os.path.exists(new_name_with_path)
        level += 1
    if not check_folder_exists_g(new_name_with_path, folder_to_download_g) and (not already_uploaded or overwrite):
        for item in list_blobs_g(folder_to_download_g):
            file_path_g = item.name
            file_name = trim_file_depth(file_path_g, start = file_depth)
            local_path = os.path.join(new_name_with_path, file_name)
            download_file_g(file_path_g, local_path)             


def make_folder_g(folder_name, bkt = b):
    blob = bkt.blob(folder_name + '/')
    blob.upload_from_string('')

def path_exists_g(file, bkt = b):
    blob = bkt.blob(file)
    return blob.exists()

# %%
# upload_file_g("/mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Oyster Test Videos/GOPR0018.MP4", "GOPR1077-23.mp4")

# %%
if not path_exists_g('Files/'):
    make_folder_g('Files')
    make_folder_g('Files/Video_raw')
    make_folder_g('Files/Video_ann')
    make_folder_g('Files/Image_raw')
    make_folder_g('Files/Image_ann')
    make_folder_g('Files/Model')
    make_folder_g('Files/Roboflow')
make_folder(temp_folder)
# Out:
# ./Files_local already exists

# %%
db_main = 'test_4'
cur_name = 'ab'

# %%
class SQLSess():
    def __init__(self, db_main = 'test_4', user = 'root', sql_password = 'dbuserdbuser', host = 'localhost', port = 3306):
        self.temp_folder = os.path.join('.', 'Files_local')
        self.sm = Storage_Manager()
        self.connect_to_sql()
        if not self.sm.path_exists_g('Files/'):
            self.sm.make_folder_g('Files')
            self.sm.make_folder_g('Files/Video_raw')
            self.sm.make_folder_g('Files/Video_ann')
            self.sm.make_folder_g('Files/Image_raw')
            self.sm.make_folder_g('Files/Image_ann')
            self.sm.make_folder_g('Files/Model')
            self.sm.make_folder_g('Files/Roboflow')
        make_folder(temp_folder)

        self.bba = sv.BoxCornerAnnotator()
        self.la = sv.LabelAnnotator(text_scale = 0.4, text_padding = 1)
        self.cur_name = None
        self.cur = None
        self.recent_raw_photo_id = None

        self.lfh = LocalFileHelper()
        self.db_main = db_main
        self.user = user
        self.password = sql_password
        self.host = host
        self.port = port
        



    def connect_to_sql(self):
        sql_conn = pymysql.connect(
            user=self.user,
            password=self.password,
            host=self.host,
            port=self.port,
            database=self.db_main,
            cursorclass=pymysql.cursors.DictCursor,
            autocommit=True)
        self.cur = sql_conn.cursor()
        res = cur.execute("SELECT 1")
        res = cur.fetchall()
        print(res)


    def _annotate_image(self, input_img, model, label_annotator = la, bounding_box_annotator = bba, verbose = False, conf = True, conf_level = 0.05):
        
        cont_img = np.ascontiguousarray(input_img, dtype=np.uint8)
        results = model(cont_img, conf=conf_level, verbose = verbose)[0]
        conf_array = np.array(results.boxes.conf.cpu())
        conf_ls_str  = [str(round(x * 100) ) + '%' for x in conf_array]
        tot_time = sum([x for x in results.speed.values()])
        
        detections = sv.Detections.from_ultralytics(results)
        annotated_image = bounding_box_annotator.annotate(
            scene=input_img, detections=detections)
        num_oysters = detections.xyxy.shape[0]
        annotated_image = label_annotator.annotate(
            scene=annotated_image, detections=detections, labels = conf_ls_str)
        return(annotated_image, num_oysters, tot_time, detections)


    def _annotate_video(self, input_vid, model, out_location = '.', im_width = 416, im_height = 416, conf_level = 0.3):
        tot_oysters = 0
        tot_frame = 0
        
        bba = sv.BoundingBoxAnnotator()
        la = sv.LabelAnnotator()

        container = av.open(input_vid)
        stream_vid = container.streams.video[0]
        fname = input_vid.rsplit('/', 1)[-1]
        per_index = fname.index('.')
        out_path = os.path.join(out_location, f'{fname[:per_index]}_annotated.mp4')
        outp = av.open(out_path, 'w')
        codec_name = stream_vid.codec_context.name
        fps = stream_vid.codec_context.rate
        output_stream = outp.add_stream(codec_name, str(fps))
        output_stream.width = im_width
        output_stream.height = im_height
        output_stream.pix_fmt = stream_vid.codec_context.pix_fmt
        start = time()
        for index, frame in enumerate(container.decode(stream_vid)):
            pil_img = frame.to_image()
            np_img = np.array(pil_img)
            np_img_resize = cv2.resize(np_img, (im_width, im_height))
            np_rot = np_img_resize[:, :, ::-1]
            small_pil_img = Image.fromarray(np_rot)
            np_image_2 = np.array(small_pil_img)
            an_mg, num_oysters, _, _2 = self._annotate_image(np_image_2, model, conf_level = conf_level)
            tot_oysters += num_oysters
            frame_out = av.VideoFrame.from_ndarray(an_mg, format='bgr24')
            pkt = output_stream.encode(frame_out)
            outp.mux(pkt)
        end = time()
        net_time = end - start
        container.close()
        outp.close()
        ann_rate = (index / fps) / net_time # ratio of time to annotate versus length of video
        return tot_oysters / index, net_time, out_path, ann_rate

    def add_user(self, name, user_password):
        '''
        Returns: name if query is successful, 0 if not
        '''

        try:
            self.cur.execute(f"INSERT INTO people (Username, Password, Time_Created) VALUES ('{name}', '{user_password}', CURRENT_TIMESTAMP );")
        except IntegrityError:
            print(f"Data Integrity Violated: Duplicate User with {name}")
        return name

    def add_photo(self, name, fpath, notes = '', f_out = 'Files/Image_raw'):
        '''
        Returns: Index of added photo if successful, 0 if not
        '''

        im = Image.open(fpath)
        width = im.size[0]
        height = im.size[1]
        fsize = os.stat(fpath).st_size
        ext = lfh.get_ext(fpath)
        f_temp = lfh.get_temp_fname(fpath)
        im.save(f_temp)
        self.cur.execute(f"INSERT INTO raw_files (Username, Filepath, Local_Path, Size, Type, Extension, Notes, Width, Height, Time_Uploaded) VALUES ('{name}', 'REPLACE', '{f_temp}', {fsize}, 'Image', '{ext}', '{notes}', {width}, {height}, CURRENT_TIMESTAMP);")
        self.recent_raw_photo_id = lfh.get_REPLACE_ID()

        f_id_name_g = lfh.get_id_fname(f_out, fpath, self.recent_raw_photo_id)
        temp_fname = lfh.get_temp_fname(f_id_name_g)
        print(temp_fname)
    #     print(f_temp, f_id_name)
        sm.upload_file_g(fpath, f_id_name_g)
        cur.execute(f"UPDATE raw_files SET Filepath = '{f_id_name_g}', Local_Path = '{temp_fname}' WHERE Raw_File_ID = {self.recent_raw_photo_id};")
        return self.recent_raw_photo_id

    def add_video(name, fpath, notes = '', f_out = 'Files/Video_raw'):
        '''
        Returns: Index of added video if successful, 0 if not
        '''
        cap = cv2.VideoCapture(fpath)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fsize = os.stat(fpath).st_size
        ext = get_ext(fpath)
        
        f_temp = get_temp_fname(fpath)
        
        cur.execute(f"INSERT INTO raw_files (Username, Filepath, Local_Path, Size, Type, Extension, Notes, Width, Height, Time_Uploaded) VALUES ('{name}', 'REPLACE', 'REPLACE', {fsize}, 'Video', '{ext}', '{notes}', {width}, {height}, CURRENT_TIMESTAMP);")
        id = get_REPLACE_ID()
        f_id_name_g = get_id_fname(f_out, fpath, id)
        temp_path = get_temp_fname(f_id_name_g)
    #     print(temp_path)
        
    #     print(fpath, f_id_name_g)
        upload_file_g(fpath, f_id_name_g)
        
        sh.copyfile(fpath, f_id_name_g)

        cur.execute(f"UPDATE raw_files SET Filepath = '{f_id_name_g}', Local_Path = '{temp_path}' WHERE Raw_File_ID = {id};")

        fps = cap.get(cv2.CAP_PROP_FPS)
        color_order = 'RGB' # FIXME - cant figure out how to extract from cv2 object
        
        

        cur.execute(f"INSERT INTO videos (Raw_File_ID, FPS, Color_Order) VALUES ('{id}', '{fps}', '{color_order}');")

        return id

# %%
def connect_to_sql():
    sql_conn = pymysql.connect(
        user="root",
        password="dbuserdbuser",
        host="localhost",
        port=3306,
        database=db_main,
        cursorclass=pymysql.cursors.DictCursor,
        autocommit=True)

    cur = sql_conn.cursor()
    res = cur.execute("SELECT 1")
    res = cur.fetchall()
    res
# Out:
# [{'1': 1}]

# %%
def add_user(name, password):
    '''
    Returns: name if query is successful, 0 if not
    '''

    try:
        cur.execute(f"INSERT INTO people (Username, Password, Time_Created) VALUES ('{name}', '{password}', CURRENT_TIMESTAMP );")
    except IntegrityError:
        print(f"Data Integrity Violated: Duplicate User with {name}")
    return name
add_user(cur_name, '123')
# Out:
# Data Integrity Violated: Duplicate User with ab
# 'ab'

# %%
def add_photo(name, fpath, notes = '', f_out = 'Files/Image_raw'):
    '''
    Returns: Index of added photo if successful, 0 if not
    '''

    im = Image.open(fpath)
    width = im.size[0]
    height = im.size[1]
    fsize = os.stat(fpath).st_size
    ext = get_ext(fpath)
    f_temp = get_temp_fname(fpath)
    im.save(f_temp)
    cur.execute(f"INSERT INTO raw_files (Username, Filepath, Local_Path, Size, Type, Extension, Notes, Width, Height, Time_Uploaded) VALUES ('{name}', 'REPLACE', '{f_temp}', {fsize}, 'Image', '{ext}', '{notes}', {width}, {height}, CURRENT_TIMESTAMP);")
    id = get_REPLACE_ID()

    f_id_name_g = get_id_fname(f_out, fpath, id)
    temp_fname = get_temp_fname(f_id_name_g)
    print(temp_fname)
#     print(f_temp, f_id_name)
    upload_file_g(fpath, f_id_name_g)
    cur.execute(f"UPDATE raw_files SET Filepath = '{f_id_name_g}', Local_Path = '{temp_fname}' WHERE Raw_File_ID = {id};")
    return id

SOME_IMAGE_PATH = "/mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/problem_photo.jpg"

id_raw_photo = add_photo(cur_name, fpath = SOME_IMAGE_PATH, notes = 'from HPC')
# Out:
# ./Files_local/problem_photo-38.jpg

# %%
import cv2
def add_video(name, fpath, notes = '', f_out = 'Files/Video_raw'):
    '''
    Returns: Index of added video if successful, 0 if not
    '''
    cap = cv2.VideoCapture(fpath)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fsize = os.stat(fpath).st_size
    ext = get_ext(fpath)
    
    f_temp = get_temp_fname(fpath)
    
    cur.execute(f"INSERT INTO raw_files (Username, Filepath, Local_Path, Size, Type, Extension, Notes, Width, Height, Time_Uploaded) VALUES ('{name}', 'REPLACE', 'REPLACE', {fsize}, 'Video', '{ext}', '{notes}', {width}, {height}, CURRENT_TIMESTAMP);")
    id = get_REPLACE_ID()
    f_id_name_g = get_id_fname(f_out, fpath, id)
    temp_path = get_temp_fname(f_id_name_g)
#     print(temp_path)
    
#     print(fpath, f_id_name_g)
    upload_file_g(fpath, f_id_name_g)
    
    sh.copyfile(fpath, f_id_name_g)

    cur.execute(f"UPDATE raw_files SET Filepath = '{f_id_name_g}', Local_Path = '{temp_path}' WHERE Raw_File_ID = {id};")

    fps = cap.get(cv2.CAP_PROP_FPS)
    color_order = 'RGB' # FIXME - cant figure out how to extract from cv2 object
    
    

    cur.execute(f"INSERT INTO videos (Raw_File_ID, FPS, Color_Order) VALUES ('{id}', '{fps}', '{color_order}');")

    return id

SOME_VIDEO_PATH = "/mnt/linuxlab/home/mstaus1/Desktop/Shellfish_project_2024/Jupyter_local_code/GOPR1077_tr.mp4"
id_raw_video = add_video(cur_name, SOME_VIDEO_PATH, notes='on new computer')

# %%
def download_weight(path, ver): # one of ['n', 's', 'm', 'b', 'x', 'l']
    valid_ver = ['n', 's', 'm', 'b', 'x', 'l']
    if ver not in valid_ver:
        assert InvalidVersionError('Invalid version selected. Must be one of: n, s, m, l, b, x,  for nano, small, medium, large, big extra big respectively')
    prefix = "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10"
    suffix = ".pt"
    web_path = prefix + ver + suffix
    computer_path = os.path.join(path, 'yolov10' + ver + suffix)
    if not os.path.exists(computer_path):
        wget.download(web_path, out = path)
    return computer_path

# def get_weights(f_weights_g = 'Files/Weights'): # TODO - create weights table
#     temp_weights = os.path.join(temp_folder, "Weights")
#     make_folder(temp_weights)
#     prefix = "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10"
#     versions = ['n', 's', 'm', 'b', 'x', 'l']
#     suffix = ".pt"
#     for ver in versions:
#         cur_file = 'yolov10' + ver + suffix
#         web_path = prefix + ver + suffix
#         computer_path = os.path.join(temp_weights, cur_file)
#         if not os.path.exists(computer_path):
#             wget.download(web_path, out = temp_weights)
    
#     upload_folder_g(temp_weights, f_weights_g)
    
# get_weights()

# %%
def download_roboflow(api_key, workspace, project, version, download, location):
    # if not os.path.exists(folder_roboflow):
    rf = Roboflow(api_key = api_key)
    project = rf.workspace(workspace).project(project)
    version = project.version(version)
    dat = version.download(download, location = location)
    
    fpath = os.path.join(location, 'data.yaml')
    
    with open(fpath) as f1:
        lines = f1.readlines()
    with open(fpath, 'w') as f2:
        f2.writelines(lines[:-4])
        f2.write("test: ../test/images\ntrain: ../train/images\nval: ../valid/images\n\n")

# %%
def add_roboflow(name, export_string, f_out = 'Files/Roboflow', f_weights = "Files/Weights"):
    
    '''
    Returns: Index of added roboflow if successful, 0 if not
    '''
    pattern_api = r'api_key\s*=\s*"([^"]+)"'
    api_key_lab = get_match(pattern_api, export_string)

    pattern_workspace = r'rf\.workspace\("([^"]+)"\)'
    workspace_lab = get_match(pattern_workspace, export_string)

    pattern_project = r'project\("([^"]+)"\)'
    project_lab = get_match(pattern_project, export_string)

    pattern_version = r'version\((\d+)\)'
    version_lab = get_match(pattern_version, export_string)

    pattern_download = r'\bdownload\("([^"]+)"\)'
    download_lab = get_match(pattern_download, export_string)
    
#     f_temp = get_temp_fname(f_out)
    folder_name = f'{workspace_lab}_{project_lab}_{version_lab}_{download_lab}'
    f_temp = os.path.join(temp_folder, folder_name)
    
    folder_g = os.path.join(f_out, folder_name)
#     folder_roboflow = f"{f_out}/{workspace_lab}_{project_lab}_{version_lab}_{download_lab}"
    print(api_key_lab, workspace_lab, project_lab, version_lab, download_lab, f_temp)
    # download_roboflow(api_key_lab, workspace_lab, project_lab, version_lab, download_lab, f_temp)
    
    upload_folder_g(f_temp, folder_g)
    
    cur.execute(f"INSERT INTO roboflow (Api_Key, Workspace, Project, Version, Download, Dataset_Location, Local_Path, Username, Timestamp) VALUES ('REPLACE', '{workspace_lab}', '{project_lab}', '{version_lab}', '{download_lab}', '{f_temp}', '{f_temp}', '{name}', CURRENT_TIMESTAMP);")
    
    id = get_REPLACE_ID('Roboflow_ID', 'roboflow', 'Api_Key')
    
    cur.execute(f"UPDATE roboflow SET Api_Key = '{api_key_lab}' WHERE Roboflow_ID = {id};")
    
    return id
    
id_rob = add_roboflow(cur_name, \
"""
rf = Roboflow(api_key="YGXCqFJKogQa7WbavueN")
project = rf.workspace("oyster-pt-3").project("oyt")
version = project.version(7)
dataset = version.download("yolov9")

""" )
# Out:
# YGXCqFJKogQa7WbavueN
# oyster-pt-3
# oyt
# 7
# yolov9
# YGXCqFJKogQa7WbavueN oyster-pt-3 oyt 7 yolov9 ./Files_local/oyster-pt-3_oyt_7_yolov9

# %%
# download_folder_g("Files/Roboflow/curvy-oysters_oysters-cjt7n_19_yolov8", "./Files_local/curvy-oysters_oysters-cjt7n_19_yolov8")

# %%
# upload_file_g('./runs/detect/train2/weights/best.pt', f'./Files/Model/{2000}.pt')

# %%
def add_model(roboflow_ID, f_out = "Files/Model", size_mod = 'n', weights_path_g = "Files/Weights", epochs = 10, batch = 32):
    
    weights_path = download_weight(temp_folder, size_mod)
    
    
    cur.execute(f"SELECT * FROM roboflow WHERE Roboflow_ID = {roboflow_ID}")
    res = cur.fetchall()[-1]
    print(res)

    download_roboflow(res['Api_Key'], res['Workspace'], res['Project'], res['Version'], res['Download'], res['Dataset_Location'])
    
    
#     dataset_loc_g = res['Dataset_Location']
    
#     dataset_temp = get_temp_fname(dataset_loc_g)
    
#     print(dataset_loc_g, dataset_temp)
    
#     download_folder_g(dataset_loc_g, dataset_temp)
    
    pt = os.path.join(os.getcwd(), res['Dataset_Location'][len('./'):], 'data.yaml')

    # !yolo task=detect mode=train epochs={epochs} batch={batch} plots=False model={weights_path} data={pt}
    
    samp_photo = os.path.join(res['Dataset_Location'], 'test', 'images')
    first_photo = os.listdir(samp_photo)[0]
    im = Image.open(os.path.join(samp_photo, first_photo))
    width = im.size[0]
    height = im.size[1]
                                                               
    cur.execute(f"""INSERT INTO models (Timestamp_Created, Model_Points_Path, Local_Path, Version, 
                 Hyperparams, Epoch, Batch, Model_Type, Width_Training_Images, Height_Training_Images, 
                 Size, Roboflow_ID) values (CURRENT_TIMESTAMP, 'REPLACE', 'REPLACE', 10, NULL, {epochs}, {batch}, 
                 'YOLO', {width}, {height}, '{size_mod}', {roboflow_ID})
                 """)
    
    id_mod = get_REPLACE_ID(column_id = 'Model_ID', table='models', column_rep='Model_Points_Path')
    pts_name = f'{id_mod}.pt'
    model_path_g = os.path.join(f_out, pts_name)
    pts_path = './runs/detect/train/weights/best.pt'
    temp_save_path = os.path.join(temp_folder, pts_name)
    upload_file_g(pts_path, model_path_g)
    os.rename(pts_path, temp_save_path) # for later inference
    
    cur.execute(f"UPDATE models SET Model_Points_Path = '{model_path_g}', Local_Path = '{temp_save_path}' WHERE Model_ID = {id_mod};")

    delete_folder('runs')
    return id_mod

id_mod = add_model(id_rob,epochs=1, size_mod = 'n')
# Out:
# {'Roboflow_ID': 21, 'Api_Key': 'YGXCqFJKogQa7WbavueN', 'Workspace': 'oyster-pt-3', 'Project': 'oyt', 'Version': 7, 'Download': 'yolov9', 'Username': 'ab', 'Timestamp': datetime.datetime(2024, 6, 28, 15, 27, 26), 'Dataset_Location': './Files_local/oyster-pt-3_oyt_7_yolov9', 'Local_Path': './Files_local/oyster-pt-3_oyt_7_yolov9'}
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ./Files_local/oyster-pt-3_oyt_7_yolov9 to yolov9:: 100%|██████████| 97782/97782 [00:07<00:00, 13885.94it/s]
# Extracting Dataset Version Zip to ./Files_local/oyster-pt-3_oyt_7_yolov9 in yolov9::   7%|▋         | 281/4276 [00:18<04:48, 13.84it/s]

# %%
ann_photo_id = 0
id_vid = 0

# %%
def ann_img(Raw_File_ID, Model_ID, threshold = 0.3, notes = '', f_out = 'Files/Image_ann'):
    cur.execute(f"SELECT * FROM raw_files WHERE Raw_File_ID = {Raw_File_ID}")
    cur_photo = cur.fetchall()[-1]

    cur.execute(f"SELECT * FROM models WHERE Model_ID = {Model_ID}")
    cur_model = cur.fetchall()[-1]

    cur.execute(f"SELECT * from annotated_files WHERE Model_ID = {Model_ID} AND Raw_File_ID = {Raw_File_ID}")
    res = cur.fetchall()
    if res:
        print('Image Already Annotated')
        return res[-1]['Ann_File_ID']
    
    download_file_g(cur_photo['Filepath'], cur_photo['Local_Path'])
    im = Image.open(cur_photo['Local_Path'])
    np_img = np.array(im)

    download_file_g(cur_model['Model_Points_Path'], cur_model['Local_Path'])
    model = YOLOv10(cur_model['Local_Path'])
    annot, num_oysters, tot_time, end_ann_data = annotate_image(np_img, model, conf_level = threshold)

    cur.execute(f"INSERT INTO annotated_files (Raw_File_ID, Model_ID, Annotated_Filepath, Time_to_Annotate, Confidence_Threshold, Notes, Timestamp) VALUES ('{Raw_File_ID}', '{Model_ID}', 'REPLACE', '{tot_time}', {threshold}, '{notes}', CURRENT_TIMESTAMP);")
    id = get_REPLACE_ID(column_id = 'Ann_File_ID', table='annotated_files', column_rep='Annotated_Filepath')
    f_id_name_g = get_id_fname(f_out, cur_photo['Filepath'], id)
    f_local = get_temp_fname(f_id_name_g)
    print(f_local)

    im_f = Image.fromarray(annot)
    im_f.save(f_local)



    upload_file_g(f_local, f_id_name_g)


    cur.execute(f"UPDATE annotated_files SET Annotated_Filepath = '{f_id_name_g}', Local_Path = '{f_local}' WHERE Ann_File_ID = {id};")
    cur.execute(f"INSERT INTO annotated_photos (Ann_File_ID, Number_of_Oysters) VALUES ({id}, {num_oysters})")

    coord = end_ann_data.xyxy
    conf = end_ann_data.confidence
    names = end_ann_data.data['class_name']
    class_num = end_ann_data.class_id
    for idx in range(len(coord)):
        coord_cur = coord[idx]
        cur.execute(f"INSERT INTO oysters_in_photo (Ann_File_ID, Confidence, X1, Y1, X2, Y2, Class, Class_Index) VALUES ({id}, {conf[idx]}, {coord_cur[0]}, {coord_cur[1]}, {coord_cur[2]}, {coord_cur[3]}, '{names[idx]}', {class_num[idx]});")
    return id
#     except IntegrityError:
#         print("An exception occurred")
#         print(IntegrityError)
#         cur.execute(f"SELECT Ann_File_ID FROM annotated_files WHERE Raw_File_ID = {Raw_File_ID} AND Model_ID = {Model_ID}")
#         return(cur.fetchall()[-1]['Ann_File_ID'])

# cur.execute(f"DELETE FROM oysters_in_photo WHERE Ann_File_ID = {ann_photo_id};")  
# cur.execute(f"DELETE FROM annotated_photos WHERE Ann_File_ID = {ann_photo_id};")
# cur.execute(f"DELETE FROM annotated_files WHERE Ann_File_ID = {ann_photo_id};")

ann_photo_id = ann_img(id_raw_photo, id_mod)
# Out:
# ./Files_local/problem_photo-35-57.jpg

# %%
def ann_video(Raw_File_ID, Model_ID, notes = '', f_out = 'Files/Video_ann', threshold = 0.3):
    cur.execute(f"SELECT * FROM raw_files WHERE Raw_File_ID = {Raw_File_ID}")
    cur_video = cur.fetchall()[-1]

    cur.execute(f"SELECT * FROM models WHERE Model_ID = {Model_ID}")
    cur_model = cur.fetchall()[-1]

    cur.execute(f"SELECT * from annotated_files WHERE Model_ID = {Model_ID} AND Raw_File_ID = {Raw_File_ID}")
    res = cur.fetchall()
    if res:
        return res[-1]['Ann_File_ID']
    
    download_file_g(cur_model['Model_Points_Path'], cur_model['Local_Path'])
    
    model = YOLOv10(cur_model['Local_Path'])

    download_file_g(cur_video['Filepath'], cur_video['Local_Path'])
    
    avg_oysters, time_s, out_path, ann_rate = annotate_video(cur_video['Local_Path'], model, out_location = temp_folder, conf_level = threshold)

    cur.execute(f"INSERT INTO annotated_files (Raw_File_ID, Model_ID, Annotated_Filepath, Time_to_Annotate, Confidence_Threshold, Notes, Timestamp) VALUES ('{Raw_File_ID}', '{Model_ID}', 'REPLACE', '{time_s * 1000}', {threshold}, '{notes}', CURRENT_TIMESTAMP);")

    id = get_REPLACE_ID(column_id = 'Ann_File_ID', table='annotated_files', column_rep='Annotated_Filepath')

    f_id_name_g = get_id_fname(f_out, cur_video['Filepath'], id)
    
    f_local = get_temp_fname(f_id_name_g)
#     print(f_local, out_path, f_id_name_g)
    
    cur.execute(f"UPDATE annotated_files SET Annotated_Filepath = '{f_id_name_g}', Local_Path = '{f_local}' WHERE Ann_File_ID = {id};")

    os.rename(out_path, f_local)

    cur.execute(f"INSERT INTO annotated_videos (Ann_File_ID, Annotation_Rate, Tracing, Average_Number_of_Oysters) VALUES ({id}, {ann_rate}, 0, {avg_oysters})")

    upload_file_g(f_local, f_id_name_g)
    
    return id

# cur.execute(f"DELETE FROM oysters_in_photo WHERE Ann_File_ID = {id_vid};")  
# cur.execute(f"DELETE FROM annotated_videos WHERE Ann_File_ID = {id_vid};")
# cur.execute(f"DELETE FROM annotated_files WHERE Ann_File_ID = {id_vid};")

id_vid = ann_video(id_raw_video, id_mod)
