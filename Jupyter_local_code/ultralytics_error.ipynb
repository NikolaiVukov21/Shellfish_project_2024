# %%
# !echo $CONDA_DEFAULT_ENV
import sys
print(sys.executable)
# Out:
# base2
# /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/bin/python

# %%
# !ls /usr/bin/python3
# Out:
# /usr/bin/python3

# %%
# !pip list
# Out:
# WARNING: Ignoring invalid distribution -orch (/mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages)
# Package                       Version
# ----------------------------- --------------------
# absl-py                       2.1.0
# alabaster                     0.7.16
# altair                        5.3.0
# anyio                         4.4.0
# appdirs                       1.4.4
# argh                          0.26.2
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# astor                         0.8.1
# asttokens                     2.4.1
# async-lru                     2.0.4
# atomicwrites                  1.4.0
# attrs                         23.2.0
# av                            12.1.0
# Babel                         2.15.0
# backports.weakref             1.0.post1
# base58                        2.1.1
# beautifulsoup4                4.12.3
# bkcharts                      0.2
# ...

# %%
import site; print(site.getsitepackages())
# Out:
# ['/mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages']

# %%
# !pip show ultralytics
# Out:
# WARNING: Ignoring invalid distribution -orch (/mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages)
# Name: ultralytics
# Version: 8.1.34
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
# !echo "/mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages" > /opt/python2.7.2/lib/python2.7/site-packages/usrlocal.pth
# Out:
# h

# %%
# !pip list -v
# Out:
# WARNING: Ignoring invalid distribution -orch (/mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages)
# Package                       Version              Location                                                                    Installer
# ----------------------------- -------------------- --------------------------------------------------------------------------- ---------
# absl-py                       2.1.0                /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages pip
# alabaster                     0.7.16               /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages pip
# altair                        5.3.0                /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages pip
# anyio                         4.4.0                /mnt/linuxlab/home/mstaus1/anaconda3/envs/base2/lib/python3.9/site-packages pip
# ...
